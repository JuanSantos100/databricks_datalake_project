# %% [markdown]
# #Reading csv File

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/crm/cust_info.csv")

display(df)

# %% [markdown]
# #Write it to Bronze layer

# %%
df.write.mode("overwrite").saveAsTable("bronze.crm_custumer_info")

# %%
# %sql
SELECT * 
FROM workspace.bronze.crm_custumer_info

# %% [markdown]
# #load "prd_info.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/crm/prd_info.csv")
display(df)
df.write.mode("overwrite").saveAsTable("bronze.crm_prd_info")

# %% [markdown]
# #load "sales_details.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/crm/sales_details.csv")
display(df)
df.write.mode("overwrite").saveAsTable("bronze.crm_sales_details")

# %% [markdown]
# #load "cust_az12.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/erp/CUST_AZ12.csv")
display(df)
df.write.mode("overwrite").saveAsTable("bronze.erp_CUST_AZ12")

# %% [markdown]
# #load "LOC_A101.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/erp/LOC_A101.csv")
display(df)
df.write.mode("overwrite").saveAsTable("bronze.erp_LOC_A101")

# %% [markdown]
# #load "PX_CAT_G1V2.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/workspace/bronze/source_systems/erp/PX_CAT_G1V2.csv")
display(df)
df.write.mode("overwrite").saveAsTable("bronze.erp_PX_CAT_G1V2")
