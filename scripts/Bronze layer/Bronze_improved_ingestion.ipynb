# %%
INGESTION_CONFIG = [
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/source_systems/crm/cust_info.csv",
        "table": "crm_custumer_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/source_systems/crm/prd_info.csv",
        "table": "crm_prd_info"
    },
    {
        "source": "crm",
        "path": "/Volumes/workspace/bronze/source_systems/crm/sales_details.csv",
        "table": "crm_sales_details"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/source_systems/erp/CUST_AZ12.csv",
        "table": "erp_cust_az12"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/source_systems/erp/LOC_A101.csv",
        "table": "erp_loc_a101"
    },
    {
        "source": "erp",
        "path": "/Volumes/workspace/bronze/source_systems/erp/PX_CAT_G1V2.csv",
        "table": "erp_px_cat_g1v2"
    }
]

# %%
for table in INGESTION_CONFIG:
    print(f"Ingesting {table['source']} → workspace.bronze.{table['table']}")

    df = (
        spark.read
        .option("header", "True")
        .option("inferSchema", "True")
        .csv(table['path'])
    )

    (
        df.write
        .mode("overwrite")
        .saveAsTable(f"workspace.bronze.{table['table']}")

    )

# %%
# %sql
SELECT *
FROM workspace.bronze.erp_px_cat_g1v2
LIMIT 10
