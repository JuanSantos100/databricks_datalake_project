# %% [markdown]
# # Lógica para criação da tabelae de produtos

# %%
query = """SELECT
    ROW_NUMBER() OVER (ORDER BY pn.product_start_date, pn.product_key) AS product_RN, -- Surrogate key
    pn.product_id,
    pn.product_key,
    pn.product_name,
    pn.category_id,
    pc.category,
    pc.subcategory,
    pc.maintenance_flag,
    pn.product_line,
    pn.product_start_date
FROM silver.crm_products pn
LEFT JOIN silver.erp_product_category pc
    ON pn.category_id = pc.category_id
--WHERE pn.product_end_date IS NULL; -- Filter out all historical data
"""

df = spark.sql(query)

# %% [markdown]
# # Verifica a criação do dataframe

# %%
df.limit(5).display()

# %% [markdown]
# # Realiza escrita na tabela esquema gold

# %%
df.write.mode('overwrite').format('delta').saveAsTable('workspace.gold.dim_products')

# %% [markdown]
# # Verifica criação da tabela

# %%
# %sql
select * 
from workspace.gold.dim_products
limit 2
